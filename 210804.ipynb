# %%
import pandas as pd

# %%
region = pd.read_csv("./data/preprocessing/시군구_목록.csv", encoding = "euc-kr")

# %%
region.count
# Out:
# <bound method DataFrame.count of      SIG_CD    SIG_ENG_NM SIG_KOR_NM
# 0     11110     Jongno-gu        종로구
# 1     11140       Jung-gu         중구
# 2     11170    Yongsan-gu        용산구
# 3     11200  Seongdong-gu        성동구
# 4     11215   Gwangjin-gu        광진구
# ..      ...           ...        ...
# 245   48870   Hamyang-gun        함양군
# 246   48880  Geochang-gun        거창군
# 247   48890  Hapcheon-gun        합천군
# 248   50110       Jeju-si        제주시
# 249   50130   Seogwipo-si       서귀포시
#
# [250 rows x 3 columns]>

# %%
df.시군구
# Out:
# 0       종로구
# 1        중구
# 2       용산구
# 3       성동구
# 4       광진구
#        ...
# 245     함양군
# 246     거창군
# 247     합천군
# 248     제주시
# 249    서귀포시
# Name: 시군구, Length: 250, dtype: object

# %%
df = pd.read_csv("./data/preprocessing/예방가능입원률_2019_국립중앙의료원.csv")
df
# Out:
#          시/도 시/군/구   고혈압  울혈성심부전   협심증  당뇨 급성 합병증  당뇨 만성 합병증  성인 천식  \
# 0      서울특별시   종로구  15.9     2.6   3.9        0.3        4.8    1.1
# 1      서울특별시    중구  19.3     2.8   4.9        0.2        5.2    1.3
# 2      서울특별시   용산구  18.5     2.4   4.5        0.3        6.2    1.3
# 3      서울특별시   성동구  20.3     3.4   6.2        0.3        5.4    1.2
# 4      서울특별시   광진구  19.9     4.6   8.1        0.2        5.6    1.7
# ..       ...   ...   ...     ...   ...        ...        ...    ...
# 245     경상남도   함양군  28.7     5.4   4.8        0.3        7.6    3.0
# 246     경상남도   거창군  25.0     3.9   4.4        0.2        6.8    1.9
# 247     경상남도   합천군  25.8     4.5   4.5        0.2        6.4    2.1
# 248  제주특별자치도   제주시  18.6     5.5  11.2        0.3        6.5    2.3
# 249  제주특별자치도  서귀포시  18.9     6.5   9.4        0.2        6.5    2.4
#
#      만성 폐쇄성 폐질환  세균성 폐렴  요로 감염증  충수 돌기 소아 천식  소아 위장 관염  소아 세균성 폐렴  소아 요로 감염  \
# ...

# %%
df = df.drop(labels = "Unnamed: 17", axis = 1)

# %%
df.columns
# Out:
# Index(['시/도', '시/군/구', '고혈압', '울혈성심부전', '협심증', '당뇨 급성 합병증', '당뇨 만성 합병증',
#        '성인 천식', '만성 폐쇄성 폐질환', '세균성 폐렴', '요로 감염증', '충수 돌기', '소아 천식', '소아 위장 관염',
#        '소아 세균성 폐렴', '소아 요로 감염', '소아 천공성 충수염'],
#       dtype='object')

# %%
df.columns = ['시도', '시군구', '고혈압', '울혈성심부전', '협심증', '당뇨 급성 합병증', '당뇨 만성 합병증',
       '성인 천식', '만성 폐쇄성 폐질환', '세균성 폐렴', '요로 감염증', '충수 돌기', '소아 천식', '소아 위장 관염',
       '소아 세균성 폐렴', '소아 요로 감염', '소아 천공성 충수염']

# %%
region.columns = ['ID', '영문이름', '지역명']
region.지역명
# Out:
# 0       종로구
# 1        중구
# 2       용산구
# 3       성동구
# 4       광진구
#        ...
# 245     함양군
# 246     거창군
# 247     합천군
# 248     제주시
# 249    서귀포시
# Name: 지역명, Length: 250, dtype: object
